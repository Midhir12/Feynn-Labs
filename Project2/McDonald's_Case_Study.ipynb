# %% [markdown]
# ## **Feynn Labs - Machine Learning Internship**

# %% [markdown]
# ### **Task - McDonald's Case Study Replication**

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from statsmodels.graphics.mosaicplot import mosaic
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %% [markdown]
# ### **Collecting Data**

# %%
# Loading the dataset
df = pd.read_csv('/content/mcdonalds.csv')

# %% [markdown]
# ### **Exploring Data**

# %%
# Reading the top 5 rows
df.head(5)
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
# Reading the bottom 5 rows
df.tail()
# Out:
#      yummy convenient spicy fattening greasy fast cheap tasty expensive  \
# 1448    No        Yes    No       Yes    Yes   No    No    No       Yes
# 1449   Yes        Yes    No       Yes     No   No   Yes   Yes        No
# 1450   Yes        Yes    No       Yes     No  Yes    No   Yes       Yes
# 1451   Yes        Yes    No        No     No  Yes   Yes   Yes        No
# 1452    No        Yes    No       Yes    Yes   No    No    No       Yes
#
#      healthy disgusting          Like  Age      VisitFrequency  Gender
# 1448      No        Yes  I hate it!-5   47         Once a year    Male
# 1449     Yes         No            +2   36         Once a week  Female
# 1450      No         No            +3   52        Once a month  Female
# 1451     Yes         No            +4   41  Every three months    Male
# 1452      No        Yes            -3   30  Every three months    Male

# %%
# Shape of the dataset(rows,cols)
df.shape
# Out:
# (1453, 15)

# %%
# Columns in our dataset
df.columns
# Out:
# Index(['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap',
#        'tasty', 'expensive', 'healthy', 'disgusting', 'Like', 'Age',
#        'VisitFrequency', 'Gender'],
#       dtype='object')

# %%
# Information about our columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %%
# Converting categorical columns to numerical
df['yummy'] = df['yummy'].replace({'Yes':1 , 'No':0})
df['convenient'] = df['convenient'].replace({'Yes':1 , 'No':0})
df['spicy'] = df['spicy'].replace({'Yes':1 , 'No':0})
df['fattening'] = df['fattening'].replace({'Yes':1 , 'No':0})
df['greasy'] = df['greasy'].replace({'Yes':1 , 'No':0})
df['fast'] = df['fast'].replace({'Yes':1 , 'No':0})
df['cheap'] = df['cheap'].replace({'Yes':1 , 'No':0})
df['tasty'] = df['tasty'].replace({'Yes':1 , 'No':0})
df['expensive'] = df['expensive'].replace({'Yes':1 , 'No':0})
df['healthy'] = df['healthy'].replace({'Yes':1 , 'No':0})
df['disgusting'] = df['disgusting'].replace({'Yes':1 , 'No':0})
df.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting Like  Age      VisitFrequency  Gender
# 0        0           0   -3   61  Every three months  Female
# 1        0           0   +2   51  Every three months  Female
# 2        1           0   +1   62  Every three months  Female
# 3        0           1   +4   69         Once a week  Female
# 4        1           0   +2   49        Once a month    Male

# %%
# Extracting the eleven columns from df
df1 = df.iloc[:,0:11]
df1.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting
# 0        0           0
# 1        0           0
# 2        1           0
# 3        0           1
# 4        1           0

# %%
yummy =print(((df1['yummy'].value_counts(normalize=True)*100)[1]))
# Out:
# 55.26496902959395

# %%
convenient =print(((df1['convenient'].value_counts(normalize=True)*100)[1]))
# Out:
# 90.77770130763938

# %%
spicy =print(((df1['spicy'].value_counts(normalize=True)*100)[1]))
# Out:
# 9.359944941500343

# %% [markdown]
# 55% perceive McDonald’s as Yummy,
#  91% believe that McDonald's is Convenient, but only 9% think that
# McDonald’s food is Spicy.

# %%
# Principal Component Analysis
pca = PCA(n_components=11)
principal_components = pca.fit_transform(df1)
pca_df = pd.DataFrame(data=principal_components,columns=["PCA1","PCA2","PCA3","PCA4","PCA5","PCA6","PCA7","PCA8","PCA9","PCA10","PCA11"])
pca_df.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0  0.425367 -0.219079  0.663255 -0.401300  0.201705 -0.389767 -0.211982
# 1 -0.218638  0.388190 -0.730827 -0.094724  0.044669 -0.086596 -0.095877
# 2  0.375415  0.730435 -0.122040  0.692262  0.839643 -0.687406  0.583112
# 3 -0.172926 -0.352752 -0.843795  0.206998 -0.681415 -0.036133 -0.054284
# 4  0.187057 -0.807610  0.028537  0.548332  0.854074 -0.097305 -0.457043
#
#        PCA8      PCA9     PCA10     PCA11
# 0  0.163235  0.181007  0.515706 -0.567074
# 1 -0.034756  0.111476  0.493313 -0.500440
# 2  0.364379 -0.322288  0.061759  0.242741
# 3 -0.231477 -0.028003 -0.250678 -0.051034
# 4  0.171758 -0.074409  0.031897  0.082245

# %%
pca_df[['PCA1','PCA2','PCA3','PCA4','PCA5','PCA6','PCA7','PCA8','PCA9','PCA10','PCA11']].std()
# Out:
# PCA1     0.757050
# PCA2     0.607456
# PCA3     0.504619
# PCA4     0.398799
# PCA5     0.337405
# PCA6     0.310275
# PCA7     0.289697
# PCA8     0.275122
# PCA9     0.265251
# PCA10    0.248842
# PCA11    0.236903
# dtype: float64

# %% [markdown]
# The first two components
# capture more information contained in the segmentation variables.

# %%
sns.scatterplot(data=pca_df, x='PCA1', y='PCA2',palette='deep')
plt.show()

# %% [markdown]
# ### **Extracting Segments**

# %% [markdown]
# Elbow method for finding the optimal number of clusters

# %%
# Using elbow method
wcss = []
for i in range(1,11):
  # init is used for initializing the centroid
  kmeans = KMeans(n_clusters = i, init='k-means++', random_state = 10)
  kmeans.fit(df1)
  wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.xlabel(range(1,11))
plt.xlabel('No of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans2 = KMeans()
visualizer = KElbowVisualizer(kmeans2, k=(1,10))
visualizer.fit(df1)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# It appears that there is an elbow at k = 4 clusters

# %%
k_means_model = KMeans(4)
k_means_model.fit_predict(df1)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':k_means_model.labels_})],axis=1)

# %%
pca_df_kmeans.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0  0.425367 -0.219079  0.663255 -0.401300  0.201705 -0.389767 -0.211982
# 1 -0.218638  0.388190 -0.730827 -0.094724  0.044669 -0.086596 -0.095877
# 2  0.375415  0.730435 -0.122040  0.692262  0.839643 -0.687406  0.583112
# 3 -0.172926 -0.352752 -0.843795  0.206998 -0.681415 -0.036133 -0.054284
# 4  0.187057 -0.807610  0.028537  0.548332  0.854074 -0.097305 -0.457043
#
#        PCA8      PCA9     PCA10     PCA11  cluster
# 0  0.163235  0.181007  0.515706 -0.567074        3
# 1 -0.034756  0.111476  0.493313 -0.500440        1
# 2  0.364379 -0.322288  0.061759  0.242741        1
# 3 -0.231477 -0.028003 -0.250678 -0.051034        2
# 4  0.171758 -0.074409  0.031897  0.082245        3

# %%
plt.figure(figsize=(8,6))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['red','blue','green','pink','yellow'])
plt.title('K-Means Clustering')
plt.show()

# %%
k_means_model = KMeans(4)
k_means_model.fit_predict(df1)
pca_df_kmeans1= pd.concat([df1,pd.DataFrame({'cluster':k_means_model.labels_})],axis=1)
pca_df_kmeans1.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting  cluster
# 0        0           0        1
# 1        0           0        0
# 2        1           0        0
# 3        0           1        2
# 4        1           0        1

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='cluster', data=pca_df_kmeans1, hue='cluster')
plt.show()

# %%
pca_df_kmeans1['cluster'].value_counts(normalize=True)*100
# Out:
# 2    37.783895
# 0    24.294563
# 1    21.197522
# 3    16.724019
# Name: cluster, dtype: float64

# %% [markdown]
# ### **Profiling Segments**

# %%
cluster1_analysis = pca_df_kmeans1[pca_df_kmeans1['cluster']==0]
cluster1_analysis.head()
# Out:
#     yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  \
# 1       1           1      0          1       1     1      1      1
# 2       0           1      1          1       1     1      0      1
# 6       1           1      1          1       0     1      0      1
# 9       1           1      0          1       1     1      0      1
# 11      1           1      0          1       1     1      0      1
#
#     expensive  healthy  disgusting  cluster
# 1           1        0           0        0
# 2           1        1           0        0
# 6           1        1           0        0
# 9           1        0           0        0
# 11          1        0           1        0

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=cluster1_analysis[['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap', 'tasty', 'expensive', 'healthy', 'disgusting']],ci = None)
plt.title('Analysis for cluster 1')
plt.show()

# %% [markdown]
# The group of customers in Cluster1 beleive that McDonald's is yummy, convenient, fattening, fast, tasty and expensive.

# %%
cluster2_analysis = pca_df_kmeans1[pca_df_kmeans1['cluster']==1]
plt.figure(figsize=(10,6))
sns.barplot(data=cluster2_analysis[['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap', 'tasty', 'expensive', 'healthy', 'disgusting']],ci = None)
plt.title('Analysis for cluster 2')
plt.show()

# %% [markdown]
# The group of customers in Cluster2 beleive that McDonald's is convenient,fattening, greasy, fast, cheap and disgusting.

# %%
cluster3_analysis = pca_df_kmeans1[pca_df_kmeans1['cluster']==2]
plt.figure(figsize=(10,6))
sns.barplot(data=cluster3_analysis[['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap', 'tasty', 'expensive', 'healthy', 'disgusting']],ci = None)
plt.title('Analysis for cluster 3')
plt.show()

# %% [markdown]
# The group of customers in Cluster3 beleive that McDonald's is yummy, convenient,fattening, fast, cheap and tasty.

# %%
cluster4_analysis = pca_df_kmeans1[pca_df_kmeans1['cluster']==3]
plt.figure(figsize=(10,6))
sns.barplot(data=cluster4_analysis[['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap', 'tasty', 'expensive', 'healthy', 'disgusting']],ci = None)
plt.title('Analysis for cluster 4')
plt.show()

# %% [markdown]
# The group of customers in Cluster4 beleive that McDonald's is convenient,fattening, greasy, fast, expensive and disgusting

# %% [markdown]
# Overall, people find McDonald's convenient, fattening and fast

# %% [markdown]
# ### **Describing Segments**

# %%
df= pd.concat([df,pd.DataFrame({'cluster':k_means_model.labels_})],axis=1)
df.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting Like  Age      VisitFrequency  Gender  cluster
# 0        0           0   -3   61  Every three months  Female        1
# 1        0           0   +2   51  Every three months  Female        0
# 2        1           0   +1   62  Every three months  Female        0
# 3        0           1   +4   69         Once a week  Female        2
# 4        1           0   +2   49        Once a month    Male        1

# %%
df['Like'].value_counts()
# Out:
# +3              229
# +2              187
# 0               169
# +4              160
# +1              152
# I hate it!-5    152
# I love it!+5    143
# -3               73
# -4               71
# -2               59
# -1               58
# Name: Like, dtype: int64

# %%
df['Like'] = df['Like'].replace({'I hate it!-5':0 ,'-4':1, '-3':2, '-2':3, '-1':4, '0':5, '+1':6, '+2':7, '+3':8, '+4':9, 'I love it!+5':10})
df.tail()
# Out:
#       yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  \
# 1448      0           1      0          1       1     0      0      0
# 1449      1           1      0          1       0     0      1      1
# 1450      1           1      0          1       0     1      0      1
# 1451      1           1      0          0       0     1      1      1
# 1452      0           1      0          1       1     0      0      0
#
#       expensive  healthy  disgusting  Like  Age      VisitFrequency  Gender  \
# 1448          1        0           1     0   47         Once a year    Male
# 1449          0        1           0     7   36         Once a week  Female
# 1450          1        0           0     8   52        Once a month  Female
# 1451          0        1           0     9   41  Every three months    Male
# 1452          1        0           1     2   30  Every three months    Male
#
#       cluster
# 1448        3
# 1449        2
# 1450        0
# 1451        2
# 1452        3

# %%
plt.rcParams['figure.figsize']=(10,10)
mosaic(df,['Like','cluster'])
plt.xlabel('Like')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Female    788
# Male      665
# Name: Gender, dtype: int64

# %%
df['Gender'] = df['Gender'].replace({'Female':0, 'Male':1})

# %%
mosaic(df,['cluster','Gender'])
plt.xlabel('Cluster Number')
plt.show()

# %%
sns.boxplot(x=df['cluster'], y=df['Age'])
plt.xlabel('Cluster Number')
plt.show()

# %% [markdown]
# ### **Selecting the Target Segment**

# %%
df['VisitFrequency'].value_counts()
# Out:
# Once a month             439
# Every three months       342
# Once a year              252
# Once a week              235
# Never                    131
# More than once a week     54
# Name: VisitFrequency, dtype: int64

# %%
df['VisitFrequency'] = df['VisitFrequency'].replace({'Never':0, 'Once a week':1, 'More than once a week':2, 'Once a month':3, 'Every three months':4, 'Once a year':5})
df.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting  Like  Age  VisitFrequency  Gender  cluster
# 0        0           0     2   61               4       0        1
# 1        0           0     7   51               4       0        0
# 2        1           0     6   62               4       0        0
# 3        0           1     9   69               1       0        2
# 4        1           0     7   49               3       1        1

# %%
X = df.iloc[:,0:15]
Y = df.iloc[:,15]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=10)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1017, 15)
# (436, 15)

# %%
X_test.head()
# Out:
#       yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  \
# 1176      1           1      0          1       1     1      1      1
# 1332      1           1      0          1       1     1      0      1
# 941       1           0      0          1       1     1      0      1
# 878       1           1      0          1       1     1      1      1
# 35        0           1      0          1       1     1      1      0
#
#       expensive  healthy  disgusting  Like  Age  VisitFrequency  Gender
# 1176          0        1           0     9   35               3       0
# 1332          1        0           0     9   40               1       0
# 941           1        0           0     9   21               3       0
# 878           1        1           0     9   34               1       0
# 35            0        0           1     3   54               4       0

# %%
Y_test.head()
# Out:
# 1176    2
# 1332    0
# 941     0
# 878     0
# 35      1
# Name: cluster, dtype: int32

# %%
dc = DecisionTreeClassifier(random_state=1234)
model = dc.fit(X, Y)

# %%
text_representation = tree.export_text(dc)
print(text_representation)
# Out:
# |--- feature_6 <= 0.50
# |   |--- feature_7 <= 0.50
# |   |   |--- feature_0 <= 0.50
# |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |--- class: 3
# |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |--- class: 3
# |   |   |--- feature_0 >  0.50
# |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |--- class: 3
# |   |--- feature_7 >  0.50
# |   |   |--- feature_10 <= 0.50
# |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |--- feature_11 <= 7.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_11 >  7.00
# |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |--- feature_12 <= 19.50
# |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_12 >  19.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_10 >  0.50
# |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |--- class: 3
# |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |--- class: 0
# |--- feature_6 >  0.50
# |   |--- feature_7 <= 0.50
# |   |   |--- feature_8 <= 0.50
# |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- feature_8 >  0.50
# |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |--- feature_11 <= 7.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_11 >  7.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |--- class: 3
# |   |--- feature_7 >  0.50
# |   |   |--- feature_8 <= 0.50
# |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |--- class: 2
# |   |   |--- feature_8 >  0.50
# |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |--- feature_12 <= 30.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_12 >  30.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |--- feature_11 <= 0.50
# |   |   |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_11 >  0.50
# |   |   |   |   |   |--- feature_0 <= 0.50
# |   |   |   |   |   |   |--- feature_10 <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_10 >  0.50
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |   |--- class: 0

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dc, filled=True)
